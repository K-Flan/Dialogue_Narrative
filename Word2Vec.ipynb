# %% [markdown]
# # Text classification via vector semantics and open source software

# %%
from nltk.corpus import inaugural

# %% [markdown]
# Let's use the Inaugural speeches again.
#
# Grab the president's name as a label by ignoring the year and the .txt extension on each speech's file id.

# %%
train_data = [sentence for fileid in inaugural.fileids() for sentence in inaugural.sents(fileid)]
train_labels = [fileid[5:-4] for fileid in inaugural.fileids() for sent in inaugural.sents(fileid)]

# %%
train_labels
# Out:
# ['Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Washington',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Jefferson',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Madison',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Monroe',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Adams',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'Jackson',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'VanBuren',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Harrison',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  'Polk',
#  ...]

# %% [markdown]
# Let's use a pre-trained word embedding.
#
# In this case based on ~100 billion words from Google News used to represent a vocab of ~3 million words in a 300-dimension vector space.
#
# Requires a 2GB download first time loaded then fills a good 4GB RAM.

# %%
# gensim can directly access a few models and dataset
import gensim.downloader as api
api.info('word2vec-google-news-300')
# Out:
# {'num_records': 3000000,
#  'file_size': 1743563840,
#  'base_dataset': 'Google News (about 100 billion words)',
#  'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/word2vec-google-news-300/__init__.py',
#  'license': 'not found',
#  'parameters': {'dimension': 300},
#  'description': "Pre-trained vectors trained on a part of the Google News dataset (about 100 billion words). The model contains 300-dimensional vectors for 3 million words and phrases. The phrases were obtained using a simple data-driven approach described in 'Distributed Representations of Words and Phrases and their Compositionality' (https://code.google.com/archive/p/word2vec/).",
#  'read_more': ['https://code.google.com/archive/p/word2vec/',
#   'https://arxiv.org/abs/1301.3781',
#   'https://arxiv.org/abs/1310.4546',
#   'https://www.microsoft.com/en-us/research/publication/linguistic-regularities-in-continuous-space-word-representations/?from=http%3A%2F%2Fresearch.microsoft.com%2Fpubs%2F189726%2Frvecs.pdf'],
#  'checksum': 'a5e5354d40acb95f9ec66d5977d140ef',
#  'file_name': 'word2vec-google-news-300.gz',
#  'parts': 1}

# %%
wv = api.load('word2vec-google-news-300')

# %%
wv.most_similar('frog', topn=5)
# Out:
# [('frogs', 0.8018162250518799),
#  ('toad', 0.7049819231033325),
#  ('lizard', 0.6754181981086731),
#  ('Aricent_combines', 0.6699402928352356),
#  ('bullfrog', 0.6557111144065857)]

# %% [markdown]
# ## Classifying president of inaugural speech sentences

# %% [markdown]
# We can't just through the sentences into a standard classifier.

# %%
from sklearn.linear_model import LogisticRegression
LogisticRegression().fit(train_data, train_labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-5f42878ad41f> in <module>
#       1 from sklearn.linear_model import LogisticRegression
# ----> 2 LogisticRegression().fit(train_data, train_labels)
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1342         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1343                                    order="C",
# -> 1344                                    accept_large_sparse=solver != 'liblinear')
#    1345         check_classification_targets(y)
#    1346         self.classes_ = np.unique(y)
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     800                     ensure_min_samples=ensure_min_samples,
#     801                     ensure_min_features=ensure_min_features,
# --> 802                     estimator=estimator)
#     803     if multi_output:
#     804         y = check_array(y, accept_sparse='csr', force_all_finite=True,
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     596                     array = array.astype(dtype, casting="unsafe", copy=False)
#     597                 else:
# --> 598                     array = np.asarray(array, order=order, dtype=dtype)
#     599             except ComplexWarning:
#     600                 raise ValueError("Complex data not supported\n"
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# Ok, so instead let's convert the sentences to a vector instead by taking the mean of the word vectors for each sentence.

# %%
import numpy as np
# we're ignoring any words not in our embeddings vocsb
# so there is a small risk here that no words in the sentence are in the vocab which would leave an empty array
train_vecs = np.array([
    np.mean([wv[word] for word in sentence if word in wv.vocab], axis=0)
    for sentence in train_data
])

train_vecs
# Out:
# array([[ 0.01371111,  0.03740583, -0.06473214, ..., -0.00234549,
#          0.20612444,  0.08544922],
#        [ 0.00393775,  0.021065  ,  0.03127806, ..., -0.03549157,
#         -0.00971197, -0.04127293],
#        [ 0.01896888,  0.05594985,  0.03749165, ..., -0.01623395,
#          0.02293476,  0.0019733 ],
#        ...,
#        [ 0.20052083,  0.08162435,  0.02587891, ..., -0.24495442,
#         -0.08821615,  0.07167307],
#        [-0.00097656, -0.05688477,  0.10229492, ..., -0.20751953,
#         -0.19726562,  0.09008789],
#        [ 0.17285156,  0.12792969,  0.02197266, ..., -0.18684895,
#         -0.02832031,  0.05301412]], dtype=float32)

# %%
clf = LogisticRegression().fit(train_vecs, train_labels)
# Out:
# /home/henry/anaconda3/envs/dialogue/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
import pandas as pd
pd.set_option("max_rows", None)
pd.DataFrame({"predicted": clf.predict(train_vecs[:100]), "actual": train_labels[:100]})
# Out:
#      predicted      actual
# 0     McKinley  Washington
# 1     Harrison  Washington
# 2     Harrison  Washington
# 3     Harrison  Washington
# 4     Harrison  Washington
# 5     Harrison  Washington
# 6     Harrison  Washington
# 7     Harrison  Washington
# 8     Harrison  Washington
# 9     Harrison  Washington
# 10    Harrison  Washington
# 11    Harrison  Washington
# 12    Harrison  Washington
# 13    Harrison  Washington
# 14    Harrison  Washington
# 15    Harrison  Washington
# 16    Harrison  Washington
# 17    Harrison  Washington
# 18    Harrison  Washington
# 19    Harrison  Washington
# 20        Taft  Washington
# 21    Harrison  Washington
# 22    Harrison  Washington
# 23      Monroe  Washington
# 24    Harrison  Washington
# 25      Monroe  Washington
# 26    Harrison  Washington
# 27     Lincoln  Washington
# 28    Harrison       Adams
# 29    Harrison       Adams
# 30    Harrison       Adams
# 31    Harrison       Adams
# 32    Harrison       Adams
# 33    Harrison       Adams
# 34   Roosevelt       Adams
# 35    McKinley       Adams
# 36    Harrison       Adams
# 37      Monroe       Adams
# 38    Harrison       Adams
# 39      Monroe       Adams
# 40    Harrison       Adams
# 41     Lincoln       Adams
# 42    Harrison       Adams
# 43    Harrison       Adams
# 44      Monroe       Adams
# 45        Bush       Adams
# 46    Harrison       Adams
# 47    Harrison       Adams
# 48    Harrison       Adams
# 49        Bush       Adams
# 50    Harrison       Adams
# 51    Harrison       Adams
# 52    Harrison       Adams
# 53    Harrison       Adams
# 54   Roosevelt       Adams
# 55    Harrison       Adams
# 56    Harrison       Adams
# 57        Bush       Adams
# 58    Harrison       Adams
# 59    Harrison       Adams
# 60    Harrison       Adams
# 61    Harrison       Adams
# 62    Harrison       Adams
# 63   Roosevelt       Adams
# 64    Harrison       Adams
# 65      Reagan   Jefferson
# 66    Harrison   Jefferson
# 67  Eisenhower   Jefferson
# 68   Roosevelt   Jefferson
# 69      Monroe   Jefferson
# 70    Harrison   Jefferson
# 71    Harrison   Jefferson
# 72     Clinton   Jefferson
# 73   Roosevelt   Jefferson
# 74   Roosevelt   Jefferson
# 75    Harrison   Jefferson
# 76        Bush   Jefferson
# 77    Harrison   Jefferson
# 78        Bush   Jefferson
# 79    Harrison   Jefferson
# 80   Roosevelt   Jefferson
# 81   Jefferson   Jefferson
# 82      Monroe   Jefferson
# 83    Harrison   Jefferson
# 84      Reagan   Jefferson
# 85     Lincoln   Jefferson
# 86   Roosevelt   Jefferson
# 87       Nixon   Jefferson
# 88      Reagan   Jefferson
# 89    Harrison   Jefferson
# 90    Harrison   Jefferson
# 91      Monroe   Jefferson
# 92      Monroe   Jefferson
# 93    Harrison   Jefferson
# 94    Harrison   Jefferson
# 95   Roosevelt   Jefferson
# 96       Obama   Jefferson
# 97        Bush   Jefferson
# 98   Jefferson   Jefferson
# 99    Harrison   Jefferson

# %% [markdown]
# Benefits of not rolling your own:
#
# 1. Can effectively work with some much larger datasets with minimal compute resources
# 2. Can achieve a lot in a short time due to someone else having optimized code and tuned embeddings, so can focus on trying different approaches and hyperparameters.
#
# But
#
# 1. It doesn't give much insight into how word2vec (or logistic regression) works so when hit problems it's not necessarily easy to debug
# 1. Less control over what data goes into my models (maybe it contains biases that I'd like to avoid)
# 1. Still a lot of glue code

# %% [markdown]
# ### Pipelines
# Can use a Scikit Learn Pipeline to tidy-up and hide some of this glue code

# %%
from sklearn.pipeline import Pipeline

class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec

    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([wv[word] for word in sentence if word in wv.vocab], axis=0)
            for sentence in X
        ])

logreg_w2v = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(wv)),
    ("log reg", LogisticRegression())])

# %% [markdown]
# Now we can just pass the array of arrays of words as our training data for the classifier.

# %%
logreg_w2v.fit(train_data, train_labels)
# Out:
# /home/henry/anaconda3/envs/dialogue/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Pipeline(steps=[('word2vec vectorizer',
#                  <__main__.MeanEmbeddingVectorizer object at 0x7fe75ea395d0>),
#                 ('log reg', LogisticRegression())])

# %%
pd.DataFrame({"predicted": logreg_w2v.predict(train_data[:100]), "actual": train_labels[:100]})
# Out:
#      predicted      actual
# 0     McKinley  Washington
# 1     Harrison  Washington
# 2     Harrison  Washington
# 3     Harrison  Washington
# 4     Harrison  Washington
# 5     Harrison  Washington
# 6     Harrison  Washington
# 7     Harrison  Washington
# 8     Harrison  Washington
# 9     Harrison  Washington
# 10    Harrison  Washington
# 11    Harrison  Washington
# 12    Harrison  Washington
# 13    Harrison  Washington
# 14    Harrison  Washington
# 15    Harrison  Washington
# 16    Harrison  Washington
# 17    Harrison  Washington
# 18    Harrison  Washington
# 19    Harrison  Washington
# 20        Taft  Washington
# 21    Harrison  Washington
# 22    Harrison  Washington
# 23      Monroe  Washington
# 24    Harrison  Washington
# 25      Monroe  Washington
# 26    Harrison  Washington
# 27     Lincoln  Washington
# 28    Harrison       Adams
# 29    Harrison       Adams
# 30    Harrison       Adams
# 31    Harrison       Adams
# 32    Harrison       Adams
# 33    Harrison       Adams
# 34   Roosevelt       Adams
# 35    McKinley       Adams
# 36    Harrison       Adams
# 37      Monroe       Adams
# 38    Harrison       Adams
# 39      Monroe       Adams
# 40    Harrison       Adams
# 41     Lincoln       Adams
# 42    Harrison       Adams
# 43    Harrison       Adams
# 44      Monroe       Adams
# 45        Bush       Adams
# 46    Harrison       Adams
# 47    Harrison       Adams
# 48    Harrison       Adams
# 49        Bush       Adams
# 50    Harrison       Adams
# 51    Harrison       Adams
# 52    Harrison       Adams
# 53    Harrison       Adams
# 54   Roosevelt       Adams
# 55    Harrison       Adams
# 56    Harrison       Adams
# 57        Bush       Adams
# 58    Harrison       Adams
# 59    Harrison       Adams
# 60    Harrison       Adams
# 61    Harrison       Adams
# 62    Harrison       Adams
# 63   Roosevelt       Adams
# 64    Harrison       Adams
# 65      Reagan   Jefferson
# 66    Harrison   Jefferson
# 67  Eisenhower   Jefferson
# 68   Roosevelt   Jefferson
# 69      Monroe   Jefferson
# 70    Harrison   Jefferson
# 71    Harrison   Jefferson
# 72     Clinton   Jefferson
# 73   Roosevelt   Jefferson
# 74   Roosevelt   Jefferson
# 75    Harrison   Jefferson
# 76        Bush   Jefferson
# 77    Harrison   Jefferson
# 78        Bush   Jefferson
# 79    Harrison   Jefferson
# 80   Roosevelt   Jefferson
# 81   Jefferson   Jefferson
# 82      Monroe   Jefferson
# 83    Harrison   Jefferson
# 84      Reagan   Jefferson
# 85     Lincoln   Jefferson
# 86   Roosevelt   Jefferson
# 87       Nixon   Jefferson
# 88      Reagan   Jefferson
# 89    Harrison   Jefferson
# 90    Harrison   Jefferson
# 91      Monroe   Jefferson
# 92      Monroe   Jefferson
# 93    Harrison   Jefferson
# 94    Harrison   Jefferson
# 95   Roosevelt   Jefferson
# 96       Obama   Jefferson
# 97        Bush   Jefferson
# 98   Jefferson   Jefferson
# 99    Harrison   Jefferson

# %% [markdown]
# ### Training embeddings
#
# And we could create our own embeddings if we wanted to control those.

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences=train_data)

# %% [markdown]
# Let's see what this embedding is like.

# %%
model.most_similar("frog", topn=5)
# Out:
# /home/henry/anaconda3/envs/dialogue/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-8effa387a25b> in <module>
# ----> 1 model.most_similar("frog", topn=5)
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/gensim/utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/gensim/models/base_any2vec.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#    1395
#    1396         """
# -> 1397         return self.wv.most_similar(positive, negative, topn, restrict_vocab, indexer)
#    1398
#    1399     @deprecated("Method will be removed in 4.0.0, use self.wv.wmdistance() instead")
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, restrict_vocab, indexer)
#     551                 mean.append(weight * word)
#     552             else:
# --> 553                 mean.append(weight * self.word_vec(word, use_norm=True))
#     554                 if word in self.vocab:
#     555                     all_words.add(self.vocab[word].index)
#
# ~/anaconda3/envs/dialogue/lib/python3.7/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     466             return result
#     467         else:
# --> 468             raise KeyError("word '%s' not in vocabulary" % word)
#     469
#     470     def get_vector(self, word):
#
# KeyError: "word 'frog' not in vocabulary"

# %% [markdown]
# Clearly no president has used the word "frog" in their speeches. Let's try something more likely to be in a speech.

# %%
model.wv.most_similar("America", topn=5)
# Out:
# [('man', 0.9995824098587036),
#  ('God', 0.9995260238647461),
#  ('children', 0.9992741346359253),
#  ('mankind', 0.998863697052002),
#  ('money', 0.9987922310829163)]
